# %%
import os
os.chdir("/content/drive/MyDrive/yolov3")

# %%
# !git clone https://github.com/AlexeyAB/darknet
# Out:
# Cloning into 'darknet'...
# remote: Enumerating objects: 14665, done.
# remote: Total 14665 (delta 0), reused 0 (delta 0), pack-reused 14665
# Receiving objects: 100% (14665/14665), 13.24 MiB | 8.42 MiB/s, done.
# Resolving deltas: 100% (9982/9982), done.
# Checking out files: 100% (2027/2027), done.

# %%
# Configure
# %cd darknet
# !sed -i 's/OPENCV=0/OPENCV=1/' Makefile
# !sed -i 's/GPU=0/GPU=1/' Makefile
# !sed -i 's/CUDNN=0/CUDNN=1/' Makefile
# Out:
# /content/drive/My Drive/yolov3/darknet

# %%
# Compile
# !make
# Out:
# mkdir -p ./obj/
# mkdir -p backup
# chmod +x *.sh
# g++ -std=c++11 -std=c++11 -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/image_opencv.cpp -o obj/image_opencv.o
# ./src/image_opencv.cpp: In function ‘void draw_detections_cv_v3(void**, detection*, int, float, char**, image**, int, int)’:
# ./src/image_opencv.cpp:926:23: warning: variable ‘rgb’ set but not used [-Wunused-but-set-variable]
#                  float rgb[3];
#                        ^~~
# ./src/image_opencv.cpp: In function ‘void draw_train_loss(char*, void**, int, float, float, int, int, float, int, char*, float, int, int, double)’:
# ./src/image_opencv.cpp:1127:13: warning: this ‘if’ clause does not guard... [-Wmisleading-indentation]
#              if (iteration_old == 0)
# ...

# %%
# Make a copy of yolov3.cfg
# !cp cfg/yolov3.cfg cfg/yolov3_training.cfg

# %%
# Change lines in yolov3.cfg file
# !sed -i 's/batch=1/batch=64/' cfg/yolov3_training.cfg
# !sed -i 's/subdivisions=1/subdivisions=16/' cfg/yolov3_training.cfg
# !sed -i 's/max_batches = 500200/max_batches = 4000/' cfg/yolov3_training.cfg
# !sed -i '610 s@classes=80@classes=2@' cfg/yolov3_training.cfg
# !sed -i '696 s@classes=80@classes=2@' cfg/yolov3_training.cfg
# !sed -i '783 s@classes=80@classes=2@' cfg/yolov3_training.cfg
# !sed -i '603 s@filters=255@filters=21@' cfg/yolov3_training.cfg
# !sed -i '689 s@filters=255@filters=21@' cfg/yolov3_training.cfg
# !sed -i '776 s@filters=255@filters=21@' cfg/yolov3_training.cfg

# %%
# !echo -e 'Wearing Mask\nNot Wearing Mask' > /content/drive/MyDrive/yolov3/darknet/data/obj.names
# !echo -e 'classes= 2\ntrain  = /content/drive/MyDrive/yolov3/darknet/data/train.txt\nvalid  = /content/drive/MyDrive/yolov3/darknet/data/test.txt\nnames = /content/drive/MyDrive/yolov3/darknet/data/obj.names\nbackup = /content/drive/MyDrive/yolov3' > data/obj.data

# %%
# !cp /content/drive/MyDrive/yolov3/darknet/cfg/yolov3_training.cfg /content/drive/MyDrive/yolov3/yolov3_testing.cfg
# !cp /content/drive/MyDrive/yolov3/darknet/data/obj.names /content/drive/MyDrive/yolov3/classes.txt

# %%
# !mkdir /content/drive/MyDrive/yolov3/darknet/data/obj
# !unzip /content/drive/MyDrive/yolov3/images.zip -d /content/drive/MyDrive/yolov3/darknet/data/obj
# Out:
# Archive:  /content/drive/MyDrive/yolov3/images.zip
#   inflating: /content/drive/MyDrive/yolov3/darknet/data/obj/images/0_10725_jpg.rf.99ff78c82dadd6d49408164489cb6582.jpg
#   inflating: /content/drive/MyDrive/yolov3/darknet/data/obj/images/0_10725_jpg.rf.99ff78c82dadd6d49408164489cb6582.txt
#   inflating: /content/drive/MyDrive/yolov3/darknet/data/obj/images/0_8w7mkX-PHcfMM5s6_jpeg.rf.74932d662e4077ea5e4374a0038e5757.jpg
#   inflating: /content/drive/MyDrive/yolov3/darknet/data/obj/images/0_8w7mkX-PHcfMM5s6_jpeg.rf.74932d662e4077ea5e4374a0038e5757.txt
#   inflating: /content/drive/MyDrive/yolov3/darknet/data/obj/images/0_Concern-In-China-As-Mystery-Virus-Spreads_jpg.rf.3135dfc5feab288d76a4ccfd22dfc5bf.jpg
#   inflating: /content/drive/MyDrive/yolov3/darknet/data/obj/images/0_Concern-In-China-As-Mystery-Virus-Spreads_jpg.rf.3135dfc5feab288d76a4ccfd22dfc5bf.txt
# ...

# %%
import glob
images_list = glob.glob("/content/drive/MyDrive/yolov3/darknet/data/obj/images/*.jpg")
with open("/content/drive/MyDrive/yolov3/darknet/data/train.txt", "w") as f:
    f.write("\n".join(images_list))

# %%
# !wget https://pjreddie.com/media/files/darknet53.conv.74
# Out:
# --2021-01-14 08:20:53--  https://pjreddie.com/media/files/darknet53.conv.74
# Resolving pjreddie.com (pjreddie.com)... 128.208.4.108
# Connecting to pjreddie.com (pjreddie.com)|128.208.4.108|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 162482580 (155M) [application/octet-stream]
# Saving to: ‘darknet53.conv.74’
#
# darknet53.conv.74   100%[===================>] 154.96M  2.65MB/s    in 61s
#
# 2021-01-14 08:21:55 (2.53 MB/s) - ‘darknet53.conv.74’ saved [162482580/162482580]

# %%
# !./darknet detector train /content/drive/MyDrive/yolov3/darknet/data/obj.data /content/drive/MyDrive/yolov3/darknet/cfg/yolov3_training.cfg darknet53.conv.74 -dont_show
# Out:
# Streaming output truncated to the last 5000 lines.
#  total_bbox = 430512, rewritten_bbox = 0.064574 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.578651), count: 1, class_loss = 0.257868, iou_loss = 0.085789, total_loss = 0.343657
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.811015), count: 3, class_loss = 0.694324, iou_loss = 0.091195, total_loss = 0.785520
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.738679), count: 11, class_loss = 1.219922, iou_loss = 0.572097, total_loss = 1.792019
#  total_bbox = 430527, rewritten_bbox = 0.064572 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.000000), count: 1, class_loss = 0.000001, iou_loss = 0.000000, total_loss = 0.000001
# ...

# %%
# !./darknet detector train data/obj.data cfg/yolov3_training.cfg darknet53.conv.74 -dont_show
# Uncomment below and comment above to re-start your training from last saved weights
# !./darknet detector train /content/drive/MyDrive/yolov3/darknet/data/obj.data /content/drive/MyDrive/yolov3/darknet/cfg/yolov3_training.cfg /content/drive/MyDrive/yolov3/yolov3_training_last.weights -dont_show
# Out:
# Streaming output truncated to the last 5000 lines.
#  total_bbox = 9697, rewritten_bbox = 0.000000 %
#
#  3926: 0.155897, 0.268736 avg loss, 0.001000 rate, 10.047891 seconds, 251264 images, 0.243296 hours left
# Loaded: 0.000047 seconds
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.850443), count: 7, class_loss = 0.221820, iou_loss = 0.132793, total_loss = 0.354613
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.867251), count: 5, class_loss = 0.317159, iou_loss = 0.127228, total_loss = 0.444387
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = 0.000615, iou_loss = 0.000000, total_loss = 0.000615
#  total_bbox = 9709, rewritten_bbox = 0.000000 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.894769), count: 7, class_loss = 0.050038, iou_loss = 0.069349, total_loss = 0.119388
# ...
